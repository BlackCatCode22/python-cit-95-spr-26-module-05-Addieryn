# %% [markdown]
# ## Chapter 11 Exercises

# %% [markdown]
# #### Exercise 1: Write a simple program to simulate the operation of the grep command on Unix. Ask the user to enter a regular expression and count the number of lines that matched the regular expression:
# ```markdown
# $ python grep.py
# Enter a regular expression: ^Author
# mbox.txt had 1798 lines that matched ^Author
#
# $ python grep.py
# Enter a regular expression: ^X-
# mbox.txt had 14368 lines that matched ^X-
#
# $ python grep.py
# Enter a regular expression: java$
# mbox.txt had 4175 lines that matched java$

# %%
file = open('mbox-short.txt')
text = file.read().lower()

letter_dict = {}
for letter in text:
    if letter in letter_dict:
        letter_dict[letter] += 1
    else:
        letter_dict[letter] = 1

count = 0

reg_exp = input('Enter a regular expression: ')
for line in text.split('\n'):
    if reg_exp in line:
        count += 1

print(f'mbox.txt had {count} lines that matched {reg_exp}')
# Out:
# mbox.txt had 13 lines that matched are

# %% [markdown]
# #### Exercise 2: Write a program to look for lines of the form:
# ```markdown
# New Revision: 39772
# Extract the number from each of the lines using a regular expression and the findall() method. Compute the average of the numbers and print out the average as an integer.
#
# Enter file:mbox.txt
# 38549
#
# Enter file:mbox-short.txt
# 39756

# %%
import re

file_name = input('Enter file: ')
file = open(file_name).read().lower()

numbers = re.findall('new revision: ([0-9.]+)', file)
numbers = [int(num) for num in numbers]

if numbers:
    average = sum(numbers) / len(numbers)
    print(int(average))
# Out:
# 39756
